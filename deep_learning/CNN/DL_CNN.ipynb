# %% [markdown]
# ## I have learned this from sheriyans Coding School YT lecture
# ## CNN Notes Link - https://drive.google.com/file/d/15b8U3Zo3WO-v9J93Is_h2ce7WVfC5ar9/view
# ## Link of Dataset = https://www.kaggle.com/code/prashant111/mnist-deep-neural-network-with-keras/input?select=test.csv

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow import keras
from tensorflow.keras import layers
# Out:
# 2026-02-02 17:29:26.297382: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
